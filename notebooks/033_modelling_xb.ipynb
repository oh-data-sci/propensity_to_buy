# %% [markdown]
# # usage:
#
# 1. fetch feature engineered data set
# 2. select features to use.
# 3. run validation: `validate_data(sales_df, outcome, numerical_features, categorical_features)`
# 4. create a preprocessor
# 5. prepare for machine learning (standard scaler, one-hot-encoding, split train/test)
# 6. run random forest analysis
# ```
# xgb_model, xgb_metrics, xgb_feature_importance, xgb_threshold, xgb_test_proba, xgb_deciles, model_comparison = run_xgboost_analysis(
#     X_train_processed,
#     X_test_processed,
#     y_train,
#     y_test,
#     feature_names,
#     lr_metrics,
#     rf_metrics,
#     lr_test_proba,
#     rf_test_proba
# )
# ```
# 7. study performance metrics, compare against baseline models

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..', 'src'))

# %%
import duckdb
import pandas as pd
from pre_processing import (
    validate_data,                       
    create_preprocessor,                 
    get_feature_names,    
    prepare_data
)
from train_logistic_regression import run_logistic_regression_analysis
from train_random_forest       import run_random_forest_analysis
from train_xgboost             import run_xgboost_analysis

# %%
# fetch the feature engineered datatable
with duckdb.connect(database='../data/propensity_to_buy.duckdb', read_only=True) as con:
    sales_df = con.sql("SELECT * FROM feature_engineered;").df()
    sales_df = (
        sales_df
        .assign(day_of_week = sales_df['day_of_week'].astype('category')) # need to reapply categorical conversion?
        .assign(entry_hour  = sales_df['entry_hour' ].astype('category')) # need to reapply categorical conversion?
        .assign(entry_month = sales_df['entry_month'].astype('category')) # need to reapply categorical conversion?
    )
    
display(sales_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   has_placed_order           50000 non-null  bool
#  1   salary                     50000 non-null  float64
#  2   n_engaged_minutes          50000 non-null  float64
#  3   n_of_cars_viewed           50000 non-null  int64
#  4   day_of_week                50000 non-null  category
#  5   price_of_last_car_viewed   50000 non-null  float64
#  6   step_reached_in_website    50000 non-null  category
#  7   how_did_you_hear_about_us  50000 non-null  category
#  8   entry_month                50000 non-null  category
#  9   entry_hour                 50000 non-null  category
#  10  age_at_entry               50000 non-null  float64
#  11  area_code                  50000 non-null  object
#  12  entry_year                 50000 non-null  int64
#  13  minutes_per_car            50000 non-null  float64
#  14  affordability_ratio        50000 non-null  float64
#  15  industry_categories        50000 non-null  object
# dtypes: bool(1), category(5), float64(6), int64(2), object(2)
# memory usage: 4.1+ MB
# None

# %%
outcome = 'has_placed_order'
numerical_features = [
    'salary',
    'n_engaged_minutes',
    'n_of_cars_viewed', 
    'price_of_last_car_viewed',
    'age_at_entry',
    'entry_year',
    'minutes_per_car',
    'affordability_ratio'
]

categorical_features = [
    'day_of_week',
    'step_reached_in_website', 
    'how_did_you_hear_about_us', 
    # 'entry_month',
    # 'entry_hour', # try skipping this (cardinality:24)
    'area_code',
    # 'industry_categories',
]

print(f"numerical features   ({len(numerical_features)}): {numerical_features}")
print(f"categorical features ({len(categorical_features)}): {categorical_features}")
# Out:
# numerical features   (8): ['salary', 'n_engaged_minutes', 'n_of_cars_viewed', 'price_of_last_car_viewed', 'age_at_entry', 'entry_year', 'minutes_per_car', 'affordability_ratio']
# categorical features (4): ['day_of_week', 'step_reached_in_website', 'how_did_you_hear_about_us', 'area_code']

# %%
validate_data(sales_df, outcome, numerical_features, categorical_features)
preprocessor = create_preprocessor(numerical_features, categorical_features)
X_train_processed, X_test_processed, y_train, y_test, fitted_preprocessor, feature_names = prepare_data(sales_df, preprocessor, outcome, numerical_features, categorical_features)
# Out:
# === validation ===
# dataset shape: (50000, 16)
#
# data contains no missing values ✓
#
# target distribution:
# >   false (unconverted): 43,500
# >   true  (ordered):      6,500
# >   conversion rate:     13.000%
#
# categorical variable cardinalities:
# >   day_of_week: 7 unique values
# >   step_reached_in_website: 4 unique values
# >   how_did_you_hear_about_us: 5 unique values
# >   area_code: 9 unique values
# === validation completed ===
#
# dataset shape:       (50000, 15)
# target distribution: {False: 43500, True: 6500}
# conversion rate:     0.130
#
# after split:
# training set: 37500 samples (0.130 conversion rate)
# test set:     12500  samples (0.130  conversion rate)
#
# after preprocessing:
# training features shape: (37500, 29)
# test features shape:     (12500, 29)
# num features after preprocessing: 29
#   - numerical features: 8
#   - categorical features (after one-hot): 21

# %%
lr_model, lr_metrics, lr_feature_importance, lr_threshold, lr_test_proba = (
    run_logistic_regression_analysis(
        X_train_processed,
        X_test_processed,
        y_train,
        y_test,
        feature_names
    )
)
rf_model, rf_metrics, rf_feature_importance, rf_threshold, rf_test_proba, rf_deciles = run_random_forest_analysis(
    X_train_processed,
    X_test_processed,
    y_train,
    y_test,
    feature_names, 
    lr_metrics,   
    lr_test_proba 
)
# Out:
# === LOGISTIC REGRESSION BASELINE ===
#
# training complete
# training samples: 37500
# test samples:     12500
# features:         29
#
# === LOGISTIC-REGRESSION PERFORMANCE EVALUATION ===
#
# TRAINING SET PERFORMANCE:
# >   ROC-AUC:   0.8700
# >   PR-AUC:    0.3899
# >   precision: 0.3679
# >   recall:    0.8345
# >   f1-score:  0.5106
#
# TEST SET PERFORMANCE:
# >   ROC-AUC:   0.8666
# >   PR-AUC:    0.3773
# >   precision: 0.3682
# >   recall:    0.8283
# >   f1-score:  0.5098
#
# CONFUSION MATRIX (test set):
# [[8565 2310]
#  [ 279 1346]]
# true  negatives: 8565, false positives: 2310
# false negatives: 279, true  positives: 1346
#
# BUSINESS METRICS:
# >   total actual conversions:    1625
# >   total predicted conversions: 3656
# >   conversions captured:        1346 out of 1625 (82.8%)
# >   precision in predictions:    1346 out of 3656 (36.8%)
#
# === FEATURE IMPORTANCE ===
#
# TOP 15 MOST IMPORTANT FEATURES:
#                                 feature  coefficient
#                                  salary     1.814587
# step_reached_in_website_quote_generated     0.983852
#        step_reached_in_website_homepage    -0.756947
#                       n_engaged_minutes     0.566326
#  step_reached_in_website_car_configured     0.503076
#                     affordability_ratio     0.493314
#                        n_of_cars_viewed     0.382181
#                            age_at_entry     0.349338
#                             area_code_M    -0.281419
#                         area_code_other    -0.257466
#                             area_code_W    -0.213094
#                           day_of_week_6     0.203719
#                           day_of_week_3     0.199112
#                           day_of_week_2     0.169383
#                           day_of_week_1     0.165508
#
# TOP POSITIVE INFLUENCES (increase conversion probability):
#                                 feature  coefficient
#                                  salary     1.814587
# step_reached_in_website_quote_generated     0.983852
#                       n_engaged_minutes     0.566326
#  step_reached_in_website_car_configured     0.503076
#                     affordability_ratio     0.493314
#                        n_of_cars_viewed     0.382181
#                            age_at_entry     0.349338
#                           day_of_week_6     0.203719
#
# TOP NEGATIVE INFLUENCES (decrease conversion probability):
#                          feature  coefficient
# step_reached_in_website_homepage    -0.756947
#                      area_code_M    -0.281419
#                  area_code_other    -0.257466
#                      area_code_W    -0.213094
#                      area_code_E    -0.079681
#                      area_code_G    -0.069658
#                      area_code_N    -0.049360
#         price_of_last_car_viewed    -0.020218
#
# === THRESHOLD OPTIMIZATION ===
#
# failed to achieve target recall of 0.85, switching to f1-score
# optimal threshold: 0.5119
# >   precision at this threshold: 0.3732
# >   recall at this threshold: 0.8228
#
# PRECISION AT DIFFERENT RECALL LEVELS:
# >   recall 70%: precision = 0.130, threshold = 0.0029
# >   recall 75%: precision = 0.130, threshold = 0.0029
# >   recall 80%: precision = 0.130, threshold = 0.0029
# >   recall 85%: precision = 0.130, threshold = 0.0029
# >   recall 90%: precision = 0.130, threshold = 0.0029
# >   recall 95%: precision = 0.130, threshold = 0.0029
# === RANDOM FOREST MODEL ===
#
# training random forest...
# random forest model ready
# out-of-bag score not available
#
# === RANDOM-FOREST PERFORMANCE EVALUATION ===
#
# TRAINING SET PERFORMANCE:
# >   ROC-AUC:   0.8876
# >   PR-AUC:    0.4869
# >   precision: 0.3465
# >   recall:    0.9003
# >   f1-score:  0.5005
#
# TEST SET PERFORMANCE:
# >   ROC-AUC:   0.8558
# >   PR-AUC:    0.3718
# >   precision: 0.3353
# >   recall:    0.8529
# >   f1-score:  0.4814
#
# CONFUSION MATRIX (test set):
# [[8128 2747]
#  [ 239 1386]]
# true  negatives: 8128, false positives: 2747
# false negatives: 239, true  positives: 1386
#
# BUSINESS METRICS:
# >   total actual conversions:    1625
# >   total predicted conversions: 4133
# >   conversions captured:        1386 out of 1625 (85.3%)
# >   precision in predictions:    1386 out of 4133 (33.5%)
#
# === RANDOM FOREST FEATURE IMPORTANCE ===
#
# TOP 15 IMPORTANT FEATURES:
#                                 feature  importance
#                                  salary    0.372047
#                     affordability_ratio    0.286885
#                       n_engaged_minutes    0.073431
#                        n_of_cars_viewed    0.063208
#                         minutes_per_car    0.060722
#        step_reached_in_website_homepage    0.045059
#                            age_at_entry    0.031680
#                price_of_last_car_viewed    0.019076
# step_reached_in_website_quote_generated    0.018778
#  step_reached_in_website_car_configured    0.008743
#                         area_code_other    0.001723
#                              entry_year    0.001449
#                           day_of_week_1    0.001328
# how_did_you_hear_about_us_word of mouth    0.001289
#         how_did_you_hear_about_us_other    0.001236
#
# TOP FEATURES CONTRIBUTING 80% OF IMPORTANCE (4 FEATURES):
#             feature  importance  cumulative_importance
#              salary    0.372047               0.372047
# affordability_ratio    0.286885               0.658932
#   n_engaged_minutes    0.073431               0.732363
#    n_of_cars_viewed    0.063208               0.795571
#
# === THRESHOLD OPTIMIZATION ===
#
# failed to achieve target recall of 0.85, switching to f1-score
# optimal threshold: 0.5861
# >   precision at this threshold: 0.3618
# >   recall at this threshold: 0.7877
#
# PRECISION AT DIFFERENT RECALL LEVELS:
# >   recall 70%: precision = 0.130, threshold = 0.0186
# >   recall 75%: precision = 0.130, threshold = 0.0186
# >   recall 80%: precision = 0.130, threshold = 0.0186
# >   recall 85%: precision = 0.130, threshold = 0.0186
# >   recall 90%: precision = 0.130, threshold = 0.0186
# >   recall 95%: precision = 0.130, threshold = 0.0186
#
# === MODEL COMPARISON ===
#
#    metric  logistic-regression  random-forest  random-forest improvement
#   roc_auc             0.866628       0.855799                    -0.0108
#    pr_auc             0.377278       0.371840                    -0.0054
# precision             0.368162       0.335350                    -0.0328
#    recall             0.828308       0.852923                     0.0246
#  f1-score             0.509752       0.481417                    -0.0283
#
# PROBABILITY DISTRIBUTION COMPARISON:
# logistic-regression probabilities:
# >   min    : 0.0029,
# >   mean   : 0.3413
# >   median : 0.2313
# >   Max    : 0.9992
# >   std    : 0.3019
#
# random-forest probabilities:
# >   min    : 0.0186,
# >   mean   : 0.3396
# >   median : 0.2377
# >   Max    : 0.8183
# >   std    : 0.2783
#
# === RANDOM FOREST DECILE ANALYSIS ===
#
# DECILE PERFORMANCE (highest probability decile first):
#         num_leads  conversions  conversion_rate  min_prob  max_prob  avg_prob  lift  cumulative_leads  cumulative_conversions  cumulative_conversion_rate
# decile
# 10           1250          484           0.3872    0.7626    0.8183    0.7841  2.98              1250                     484                      0.3872
# 9            1250          478           0.3824    0.6884    0.7625    0.7300  2.94              2500                     962                      0.3848
# 8            1250          356           0.2848    0.5590    0.6883    0.6306  2.19              3750                    1318                      0.3515
# 7            1250          191           0.1528    0.3835    0.5590    0.4684  1.18              5000                    1509                      0.3018
# 6            1250           57           0.0456    0.2378    0.3833    0.3059  0.35              6250                    1566                      0.2506
# 5            1250           41           0.0328    0.1499    0.2377    0.1889  0.25              7500                    1607                      0.2143
# 4            1250           10           0.0080    0.1043    0.1499    0.1250  0.06              8750                    1617                      0.1848
# 3            1250            4           0.0032    0.0662    0.1043    0.0856  0.02             10000                    1621                      0.1621
# 2            1250            4           0.0032    0.0362    0.0662    0.0481  0.02             11250                    1625                      0.1444
# 1            1250            0           0.0000    0.0186    0.0362    0.0292  0.00             12500                    1625                      0.1300
#
# BUSINESS INSIGHTS:
#   top decile lift: 3.0x better than random
#   top 30% of leads capture: 1318/1625 conversions (81.1%)
#   top decile conversion rate: 38.7%

# %%
xgb_model, xgb_metrics, xgb_feature_importance, xgb_threshold, xgb_test_proba, xgb_deciles, model_comparison = run_xgboost_analysis(
    X_train_processed,
    X_test_processed,
    y_train,
    y_test,
    feature_names,
    lr_metrics,
    rf_metrics,
    lr_test_proba,
    rf_test_proba
)
# Out:
# === XGBOOST MODEL ===
#
# class imbalance ratio: 6.69
# training xgboost with early stopping
# training completed at iteration 52
# model training complete
# best iteration: 52
#
# === XGBOOST PERFORMANCE EVALUATION ===
#
# TRAINING SET PERFORMANCE:
# >   ROC-AUC:   0.9051
# >   PR-AUC:    0.5261
# >   precision: 0.3640
# >   recall:    0.9346
# >   f1-score:  0.5240
#
# TEST SET PERFORMANCE:
# >   ROC-AUC:   0.8627
# >   PR-AUC:    0.3818
# >   precision: 0.3420
# >   recall:    0.8695
# >   f1-score:  0.4909
#
# CONFUSION MATRIX (test set):
# [[8156 2719]
#  [ 212 1413]]
# true  negatives: 8156, false positives: 2719
# false negatives: 212, true  positives: 1413
#
# BUSINESS METRICS:
# >   total actual conversions:    1625
# >   total predicted conversions: 4132
# >   conversions captured:        1413 out of 1625 (87.0%)
# >   precision in predictions:    1413 out of 4132 (34.2%)
#
# === XGBOOST FEATURE IMPORTANCE ANALYSIS ===
#
#
# TOP 20 FEATURES BY WEIGHT (number of times feature is used to split):
#                                 feature  importance
#                            age_at_entry       534.0
#                                  salary       530.0
#                       n_engaged_minutes       481.0
#                     affordability_ratio       383.0
#                price_of_last_car_viewed       373.0
#                         minutes_per_car       283.0
#                        n_of_cars_viewed       238.0
# step_reached_in_website_quote_generated       104.0
#  step_reached_in_website_car_configured        52.0
#                         area_code_other        37.0
#         how_did_you_hear_about_us_other        36.0
#                           day_of_week_1        34.0
#                             area_code_W        32.0
#                           day_of_week_6        32.0
# how_did_you_hear_about_us_word of mouth        28.0
#                             area_code_M        26.0
#                             area_code_S        25.0
#                           day_of_week_3        24.0
#      how_did_you_hear_about_us_linkedin        24.0
#                           day_of_week_5        23.0
#
# TOP 20 FEATURES BY GAIN (average gain when feature is used):
#                                 feature  importance
#        step_reached_in_website_homepage  360.591644
#                                  salary  160.086945
#                        n_of_cars_viewed   75.604103
#                     affordability_ratio   65.081421
#                       n_engaged_minutes   47.426971
# step_reached_in_website_quote_generated   46.359383
#  step_reached_in_website_car_configured   34.763149
#                         minutes_per_car   34.047935
#                            age_at_entry   24.926069
#                         area_code_other   17.454983
#                             area_code_E   16.707939
#                price_of_last_car_viewed   15.924388
# how_did_you_hear_about_us_word of mouth   14.586548
#                             area_code_G   14.200115
#                           day_of_week_3   13.895732
#        how_did_you_hear_about_us_google   13.733569
#                             area_code_M   13.164135
#                           day_of_week_1   13.111821
#                             area_code_W   12.736719
#                           day_of_week_4   12.638277
#
# TOP 20 FEATURES BY COVER (average coverage when feature is used):
#                                 feature  importance
#        step_reached_in_website_homepage 2859.756104
#  step_reached_in_website_car_configured 1953.972412
#                                  salary 1592.252563
# step_reached_in_website_quote_generated 1459.309448
#                         area_code_other 1421.130371
#                        n_of_cars_viewed 1392.635498
#                       n_engaged_minutes 1032.642212
#                             area_code_M  882.462891
#                     affordability_ratio  863.037842
#                         minutes_per_car  630.469727
#                             area_code_S  621.992371
#                           day_of_week_2  618.536926
#                            age_at_entry  610.425842
#                price_of_last_car_viewed  557.916687
#                           day_of_week_6  550.049194
#                           day_of_week_4  543.709534
#                             area_code_N  503.613220
# how_did_you_hear_about_us_word of mouth  501.626526
#                             area_code_G  493.158661
#                           day_of_week_1  383.001526
#
# TOP 20 FEATURES BY TOTAL_GAIN (total gain when feature is used):
#                                 feature   importance
#                                  salary 84846.078125
#                     affordability_ratio 24926.183594
#                       n_engaged_minutes 22812.373047
#                        n_of_cars_viewed 17993.777344
#                            age_at_entry 13310.520508
#                         minutes_per_car  9635.565430
#                price_of_last_car_viewed  5939.796875
# step_reached_in_website_quote_generated  4821.375977
#        step_reached_in_website_homepage  4327.099609
#  step_reached_in_website_car_configured  1807.683716
#                         area_code_other   645.834351
#         how_did_you_hear_about_us_other   447.092651
#                           day_of_week_1   445.801910
# how_did_you_hear_about_us_word of mouth   408.423340
#                             area_code_W   407.575012
#                           day_of_week_6   356.270081
#                             area_code_M   342.267517
#                           day_of_week_3   333.497559
#        how_did_you_hear_about_us_google   302.138519
#                             area_code_S   300.462280
#
# TOP 20 FEATURES BY TOTAL_COVER (total coverage when feature is used):
#                                 feature    importance
#                                  salary 843893.875000
#                       n_engaged_minutes 496700.875000
#                        n_of_cars_viewed 331447.250000
#                     affordability_ratio 330543.500000
#                            age_at_entry 325967.406250
#                price_of_last_car_viewed 208102.921875
#                         minutes_per_car 178422.937500
# step_reached_in_website_quote_generated 151768.187500
#  step_reached_in_website_car_configured 101606.562500
#                         area_code_other  52581.824219
#        step_reached_in_website_homepage  34317.074219
#                             area_code_M  22944.035156
#                           day_of_week_6  17601.574219
#                             area_code_S  15549.809570
# how_did_you_hear_about_us_word of mouth  14045.542969
#                           day_of_week_1  13022.051758
#                           day_of_week_2  12370.738281
#                           day_of_week_4  11417.900391
#         how_did_you_hear_about_us_other  11064.011719
#                             area_code_G   9370.014648
#
# TOP FEATURES CONTRIBUTING 80% OF TOTAL GAIN (11 features):
#                                 feature  importance  cumulative_importance
#        step_reached_in_website_homepage  360.591644               0.325544
#                                  salary  160.086945               0.470071
#                        n_of_cars_viewed   75.604103               0.538327
#                     affordability_ratio   65.081421               0.597083
#                       n_engaged_minutes   47.426971               0.639900
# step_reached_in_website_quote_generated   46.359383               0.681753
#  step_reached_in_website_car_configured   34.763149               0.713138
#                         minutes_per_car   34.047935               0.743876
#                            age_at_entry   24.926069               0.766380
#                         area_code_other   17.454983               0.782138
#                             area_code_E   16.707939               0.797222
#
# === XGBOOST LEARNING CURVES ===
#
# could not plot learning curves: 'train'
#
# === THRESHOLD OPTIMIZATION ===
#
# failed to achieve target recall of 0.85, switching to f1-score
# optimal threshold: 0.6202
# >   precision at this threshold: 0.3718
# >   recall at this threshold: 0.7988
#
# PRECISION AT DIFFERENT RECALL LEVELS:
# >   recall 70%: precision = 0.130, threshold = 0.0033
# >   recall 75%: precision = 0.130, threshold = 0.0033
# >   recall 80%: precision = 0.130, threshold = 0.0033
# >   recall 85%: precision = 0.130, threshold = 0.0033
# >   recall 90%: precision = 0.130, threshold = 0.0033
# >   recall 95%: precision = 0.130, threshold = 0.0033
#
# === XGBOOST DECILE ANALYSIS ===
#
# DECILE PERFORMANCE (highest probability decile first):
#         num_leads  conversions  conversion_rate  min_prob  max_prob  avg_prob  lift  cumulative_leads  cumulative_conversions  cumulative_conversion_rate
# decile
# 10           1250          501           0.4008    0.8071    0.9063    0.8308  3.08              1250                     501                      0.4008
# 9            1250          485           0.3880    0.7396    0.8070    0.7778  2.98              2500                     986                      0.3944
# 8            1250          364           0.2912    0.5748    0.7396    0.6694  2.24              3750                    1350                      0.3600
# 7            1250          167           0.1336    0.3176    0.5747    0.4455  1.03              5000                    1517                      0.3034
# 6            1250           60           0.0480    0.1381    0.3176    0.2151  0.37              6250                    1577                      0.2523
# 5            1250           28           0.0224    0.0576    0.1381    0.0920  0.17              7500                    1605                      0.2140
# 4            1250           16           0.0128    0.0286    0.0575    0.0409  0.10              8750                    1621                      0.1853
# 3            1250            4           0.0032    0.0150    0.0286    0.0210  0.02             10000                    1625                      0.1625
# 2            1250            0           0.0000    0.0075    0.0150    0.0109  0.00             11250                    1625                      0.1444
# 1            1250            0           0.0000    0.0033    0.0075    0.0054  0.00             12500                    1625                      0.1300
#
# BUSINESS INSIGHTS:
#   top decile lift: 3.1x better than random
#   top 30% of leads capture: 1350/1625 conversions (83.1%)
#   top decile conversion rate: 40.1%
#
# ============================================================
# === COMPREHENSIVE MODEL COMPARISON ===
# ============================================================
#
# PERFORMANCE COMPARISON:
#    Metric  Logistic Regression  Random Forest  XGBoost  RF vs LR  XGB vs LR  XGB vs RF
#   ROC-AUC             0.866628       0.855799 0.862685   -0.0108    -0.0039     0.0069
#    PR-AUC             0.377278       0.371840 0.381766   -0.0054     0.0045     0.0099
# Precision             0.368162       0.335350 0.341965   -0.0328    -0.0262     0.0066
#    Recall             0.828308       0.852923 0.869538    0.0246     0.0412     0.0166
#  F1-Score             0.509752       0.481417 0.490881   -0.0283    -0.0189     0.0095
#
# BEST PERFORMERS:
#   ROC-AUC: Logistic Regression (0.8666)
#   PR-AUC: XGBoost (0.3818)
#   Precision: Logistic Regression (0.3682)
#   Recall: XGBoost (0.8695)
#   F1-Score: Logistic Regression (0.5098)
#
# PROBABILITY DISTRIBUTION COMPARISON:
#
# Logistic Regression:
#   Range: [0.0029, 0.9992]
#   Mean: 0.3413, Std: 0.3019
#   Quartiles: [0.07946201 0.23130988 0.57945009]
#
# Random Forest:
#   Range: [0.0186, 0.8183]
#   Mean: 0.3396, Std: 0.2783
#   Quartiles: [0.08551893 0.23771689 0.63481083]
#
# XGBoost:
#   Range: [0.0033, 0.9063]
#   Mean: 0.3109, Std: 0.3232
#   Quartiles: [0.02063366 0.1380823  0.67592503]
#
# BUSINESS IMPACT (Top 30% of leads):
#   Logistic Regression: 1366/1625 conversions (84.1%)
#   Random Forest: 1318/1625 conversions (81.1%)
#   XGBoost: 1350/1625 conversions (83.1%)

# %% [markdown]
# # lesson
# xgboost confirms what we have already seen, but fails to train a better predictor model. it is possible to have a decent recall, but the precision is unimpressive.
#
# what might help:
# - cross validation
# - further data wrangling, towards building more enhanced features, interactive terms
# - acquire more information on the leads
